# %% [markdown]
# # AXMT Server Notebook Smoke Test

# %%
import os, sys
print("Python executable:", sys.executable)
print("AXMT_HOME:", os.environ.get("AXMT_HOME"))
print("HF_HOME:", os.environ.get("HF_HOME"))
print("TMPDIR:", os.environ.get("TMPDIR"))
# Out:
# Python executable: /home/mabdallah/alexandriax_mt_14d/envs/axmt_py311/bin/python
# AXMT_HOME: None
# HF_HOME: None
# TMPDIR: None

# %%
import torch
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("gpu:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)

x = torch.randn(1024, 1024, device="cuda")
y = x @ x
torch.cuda.synchronize()
print("GPU test OK:", y.shape, float(y.mean()))
# Out:
# torch: 2.10.0+cu128
# cuda available: True
# gpu: NVIDIA GeForce RTX 5090
# GPU test OK: torch.Size([1024, 1024]) 0.01877560466527939

# %%
import transformers, datasets, accelerate, peft, trl, bitsandbytes as bnb, sacrebleu
print("transformers:", transformers.__version__)
print("datasets:", datasets.__version__)
print("accelerate:", accelerate.__version__)
print("peft:", peft.__version__)
print("trl:", trl.__version__)
print("bitsandbytes:", bnb.__version__)
print("sacrebleu:", sacrebleu.__version__)
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# transformers: 5.5.0
# datasets: 4.3.0
# accelerate: 1.14.0
# peft: 0.19.1
# trl: 0.24.0
# bitsandbytes: 0.49.2
# sacrebleu: 2.6.0
